# %%
import matplotlib.pyplot as plt

# %%
filename = "sum_omp_all.txt"

threads = []
times = []

with open(filename, "r") as f:
    for line in f:
        line = line.strip()
        if line.startswith("Using"):
            n = int(line.split()[1])
            threads.append(n)
        elif line.startswith("Elapsed Time:"):
            t = float(line.split()[2])
            times.append(t)

# Plot
plt.figure(figsize=(6,4))
plt.plot(threads, times, marker='o', linestyle='-')
plt.xlabel("Number of threads")
plt.ylabel("Elapsed Time (s)")
plt.title("OpenMP sum.c Scaling")
plt.grid(True)
plt.xticks(threads)
plt.show()

# %%
import base64
import os

# Generate some data to encode (e.g., random bytes or a string)
data = os.urandom(16)  # 16 bytes of random data (adjust length as needed)
# Alternatively, use a string: data = "example@email.com".encode('utf-8')
data = "ioxnrcpgzqcahsrqkz@xfavaj.com".encode('utf-8')


# Encode to URL-safe base64
url_safe_base64 = base64.urlsafe_b64encode(data).decode('utf-8').rstrip('=')
print(url_safe_base64)
# Out:
# aW94bnJjcGd6cWNhaHNycWt6QHhmYXZhai5jb20
